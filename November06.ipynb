# %%
# !pip install spacy
# !pip install ginza ja-ginza
import spacy
nlp = spacy.load('ja_ginza')
doc = nlp('今年はドジャースが優勝して大谷が大活躍，いい年だなあ．')
for sent in doc.sents:
  for token in sent:
    print(token.i, token.orth_, token.lemma_, token.pos_,
      token.tag_)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 MB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 70.7 MB/s eta 0:00:00
# ...
# 0 今年 今年 NOUN 名詞-普通名詞-副詞可能
# 1 は は ADP 助詞-係助詞
# 2 ドジャース ドジャース PROPN 名詞-固有名詞-一般
# 3 が が ADP 助詞-格助詞
# 4 優勝 優勝 VERB 名詞-普通名詞-サ変可能
# 5 し する AUX 動詞-非自立可能
# 6 て て SCONJ 助詞-接続助詞
# 7 大谷 大谷 PROPN 名詞-固有名詞-人名-姓
# 8 が が ADP 助詞-格助詞
# 9 大 大 NOUN 接頭辞
# 10 活躍 活躍 NOUN 名詞-普通名詞-サ変可能
# 11 ， , PUNCT 補助記号-読点
# 12 いい いい ADJ 形容詞-非自立可能
# 13 年 年 NOUN 名詞-普通名詞-副詞可能
# 14 だ だ AUX 助動詞
# 15 なあ なあ PART 助詞-終助詞
# 16 ． . PUNCT 補助記号-句点

# %%
'甲南'+'太郎'
# Out:
# '甲南甲南甲南'

# %%
'甲南'*3
# Out:
# '甲南甲南甲南'

# %%
len('甲南')
# Out:
# 2

# %%
name ='甲南大学,神戸大学,神戸学院大学,甲南女子大学'
name.count('大学')
# Out:
# 4

# %%
'python'[1]
# Out:
# 'y'

# %%
'python'[2:5]
# Out:
# 'tho'

# %%
't' in 'python'
# Out:
# True

# %%
'k' in 'python'
# Out:
# False

# %%
# coding: utf-8
'甲南太郎が甲南花子と一緒に甲南大学と甲南女子大学の学園祭に行った'.split('甲南')
# Out:
# ['', '太郎が', '花子と一緒に', '大学と', '女子大学の学園祭に行った']

# %%
# coding: utf-8
'甲南'.join(['私は', '太郎が', '花子と一緒に', '大学と', '女子大学の学園祭に行った'])
# Out:
# '私は甲南太郎が甲南花子と一緒に甲南大学と甲南女子大学の学園祭に行った'

# %%
t1 = '今日はいい天気です'
print(t1.replace('今日', '明日'))
# Out:
# 明日はいい天気です
