# %% [markdown]
# 準備:モジュールの導入 (Google ドライブを使用するモジュール)

# %%
# 以降はコメントとして無視される (実行されない)
import google.colab.drive

# %% [markdown]
# 準備:ドライブ使用準備(ドライブのマウント)
#
# ---

# %%
google.colab.drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# メイン処理:ファイルの読み読み込みと内容の出力

# %%
with open('/content/drive/MyDrive/AI/simple_corpus.txt') as f:
  for line in f:
    print(line)
# Out:
# Apples are red and crunchy.
#
# Bananas are sweet and soft.
#
# Grapes are small but flavorful.
#
# Oranges are easy to peel.
#
# Mangoes grow in tropical regions.
#
# Strawberries are a symbol of spring.
#
# Pineapples taste both sour and sweet.
#
# Watermelons are perfect for summer.
#
# Peaches are fragrant and tender.
#
# Kiwis are rich in vitamin C.
