# %% [markdown]
# 準備:モジュールの導入 (Google ドライブを使用するモジュール)

# %%
# 以降はコメントとして無視される (実行されない)
import google.colab.drive

# %% [markdown]
# 準備:ドライブ使用準備(ドライブのマウント)
#
# ---

# %%
google.colab.drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# メイン処理:ファイルの読み読み込みと内容の出力

# %%
with open('/content/drive/MyDrive/AI/simple_corpus.txt') as f:
  for data_line in f:
    data_line = data_line.rstrip()
    words = data_line.split(' ')
    for word in words:
      print(word, len(word))
# Out:
# Apples 6
# are 3
# red 3
# and 3
# crunchy. 8
# Bananas 7
# are 3
# sweet 5
# and 3
# soft. 5
# Grapes 6
# are 3
# small 5
# but 3
# flavorful. 10
# Oranges 7
# are 3
# easy 4
# to 2
# peel. 5
# Mangoes 7
# grow 4
# in 2
# tropical 8
# regions. 8
# Strawberries 12
# are 3
# a 1
# symbol 6
# of 2
# spring. 7
# Pineapples 10
# taste 5
# both 4
# sour 4
# and 3
# sweet. 6
# Watermelons 11
# are 3
# perfect 7
# for 3
# summer. 7
# Peaches 7
# are 3
# fragrant 8
# and 3
# tender. 7
# Kiwis 5
# are 3
# rich 4
# in 2
# vitamin 7
# C. 2
